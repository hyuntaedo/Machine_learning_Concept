# %% [markdown]
# <a href="https://colab.research.google.com/github/hyuntaedo/Machine_learning_Concept/blob/main/FastCampus_CNN%EB%AA%A8%EB%8D%B8_%EA%B5%AC%EC%A1%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <strong>CNN 모델 구조</strong>
# - Feature Extraction / Calssification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <strong>Convolution Layer</string>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 필터들이 어떻게 연산되었는지에 따라서, 필터에 따라 결정을 내리는데 중요한 역할을 한다.
# - 필터는 특징을 가지는것(Feature)

# %% [markdown]
# ##<strong>Pooling Layer</strong>
#  - 특징들을 뽑아서 수치가 높은 것들만 뽑아서 반으로 줄이는 과정
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 이미지를 압축해서 필터링

# %% [markdown]
# ## <strong>Relu</strong>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 0 의 값을 다 버림

# %% [markdown]
# ##<strong>Fully Connected</strong>
# - 계산을 하여 예측을 하는 것
# - y = w(weight)x + b(bias)
# - x 가 넣을때 9가 나오도록 w 와 b를 조정한다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##<strong>LeNet</strong>
#
# ![image.png](data:image/png;base64,...)
